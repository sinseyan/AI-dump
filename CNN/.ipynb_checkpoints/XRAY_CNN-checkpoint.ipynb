# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mat
import tensorflow as tf
from tensorflow import keras
import random
from zipfile import ZipFile
import os
import time
from shutil import copyfile
import matplotlib.pyplot as mat
from matplotlib.image import imread

# %%
train_normal = 'xray/train/NORMAL'
train_pneumonia = 'xray/train/PNEUMONIA'
test_normal = 'xray/test/NORMAL'
test_pneumonia = 'xray/test/PNEUMONIA'

# %%
train_dir_normal = os.listdir(train_normal)
train_dir_pneumonia = os.listdir(train_pneumonia)
test_dir_normal = os.listdir(test_normal)
test_fir_pneumonia = os.listdir(test_pneumonia)

# %%
mat.figure(figsize=(15,10))
for i in range(12):
    ran = random.choice((1,30))
    rand_normal = [os.path.join(train_normal, f) for f in train_dir_normal[ran:ran+1]]
    rand_pneumonia = [os.path.join(train_pneumonia, f) for f in train_dir_pneumonia[ran:ran+1]]
    rand = random.choice(rand_pneumonia+rand_normal)
    name = rand.split('/')
    name = name[-2] + ' Lungs'
    mat.subplot(3, 4, i+1)
    img = mat.imread(rand)
    mat.imshow(img,cmap = 'gray')
    mat.axis(False)
    mat.title(name)
mat.show()

# %%
sample = random.choice(train_dir_normal)
sample = imread(train_normal+"/" + sample)
samp = sample.shape
mat.imshow(sample)
print('Sample_Image_size(H*W):', samp)
# Out:
# Sample_Image_size(H*W): (1440, 1784)

# %%
x, y = [], []
for i in train_dir_normal:
    img_array = imread(train_normal +"/"+ i)
    shape = img_array.shape
    x.append(shape[0])
    y.append(shape[1])
df_shape = pd.DataFrame({'height': x, 'width': y, 'index': range(0, len(train_dir_normal))})

# %%
df_shape.head()
# Out:
#    height  width  index
# 0    1317   1857      0
# 1    1509   2111      1
# 2    1837   2031      2
# 3    1326   1663      3
# 4    1818   2053      4

# %%
import seaborn as sns
def shape(x, y, df):
    sns.catplot(kind = 'bar', x = x, y = y, data = df)

shape('index', 'height', df_shape)
shape('index', 'width', df_shape)

# %%
df_shape.describe()
# Out:
#             height        width      index
# count    74.000000    74.000000  74.000000
# mean   1539.689189  1968.094595  36.500000
# std     448.372030   340.261590  21.505813
# min     617.000000  1240.000000   0.000000
# 25%    1255.000000  1765.000000  18.250000
# 50%    1469.500000  1959.500000  36.500000
# 75%    1870.750000  2150.750000  54.750000
# max    2713.000000  2752.000000  73.000000

# %%
tr_dir = 'xray/train'
te_dir = 'xray/test'
datagen_train = keras.preprocessing.image.ImageDataGenerator(rescale = 1./255.)
train = datagen_train.flow_from_directory(tr_dir, target_size = (200,200), color_mode = 'grayscale', class_mode = 'binary', batch_size = 10)
datagen_test = keras.preprocessing.image.ImageDataGenerator(rescale = 1./255)
test = datagen_test.flow_from_directory(te_dir, target_size = (200,200), color_mode = 'grayscale', class_mode= 'binary', batch_size = 10)
# Out:
# Found 148 images belonging to 2 classes.
# Found 43 images belonging to 2 classes.

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(32, (5,5), activation = 'relu', input_shape = (200,200, 1)),
    keras.layers.MaxPool2D((2,2)),
    
    keras.layers.Conv2D(64, (3,3), activation = 'relu'),
    keras.layers.MaxPool2D(2,2),
    keras.layers.Conv2D(128, (3,3), activation = 'relu'),
    keras.layers.MaxPool2D((2,2)),
    
    keras.layers.Conv2D(256, (3,3), activation = 'relu'),
    keras.layers.MaxPool2D((2,2)),
    
    keras.layers.Flatten(),
    
    keras.layers.Dense(512, activation = 'relu'),
    keras.layers.Dropout(0.3),
    keras.layers.BatchNormalization(),
    
    keras.layers.Dense(1, activation = 'sigmoid')
])

# %%
opt = keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(loss = 'binary_crossentropy', optimizer=opt, metrics = ['accuracy'])

# %%
log_dir = os.path.join(os.curdir, 'logs')
def tensor_callback():
    file_name = time.strftime('run_%Y_%m_%d-%H_%M_%S')
    return os.path.join(log_dir, file_name)
file = tensor_callback()
tensor= keras.callbacks.TensorBoard(file)
early = keras.callbacks.EarlyStopping(patience=10)

check = keras.callbacks.ModelCheckpoint(os.curdir)
callbacks = [tensor, check, early]

# %%
history = model.fit(train, validation_data=test, epochs = 30, callbacks=callbacks)
# Out:
# Epoch 1/30
# 15/15 [==============================] - 14s 823ms/step - loss: 0.5592 - accuracy: 0.7481 - val_loss: 0.6572 - val_accuracy: 0.5116
# INFO:tensorflow:Assets written to: .\assets
# Epoch 2/30
# 15/15 [==============================] - 11s 764ms/step - loss: 0.2646 - accuracy: 0.8871 - val_loss: 0.6061 - val_accuracy: 0.6047
# INFO:tensorflow:Assets written to: .\assets
# Epoch 3/30
# 15/15 [==============================] - 11s 744ms/step - loss: 0.2183 - accuracy: 0.9181 - val_loss: 0.5672 - val_accuracy: 0.9070
# INFO:tensorflow:Assets written to: .\assets
# Epoch 4/30
# 15/15 [==============================] - 11s 756ms/step - loss: 0.1108 - accuracy: 0.9672 - val_loss: 0.5479 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 5/30
# 15/15 [==============================] - 11s 753ms/step - loss: 0.1811 - accuracy: 0.9339 - val_loss: 0.5662 - val_accuracy: 0.7209
# INFO:tensorflow:Assets written to: .\assets
# Epoch 6/30
# 15/15 [==============================] - 11s 754ms/step - loss: 0.1172 - accuracy: 0.9674 - val_loss: 0.5300 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 7/30
# 15/15 [==============================] - 11s 759ms/step - loss: 0.0735 - accuracy: 0.9785 - val_loss: 0.5057 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 8/30
# 15/15 [==============================] - 11s 751ms/step - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.9767
# INFO:tensorflow:Assets written to: .\assets
# Epoch 9/30
# 15/15 [==============================] - 12s 790ms/step - loss: 0.0572 - accuracy: 1.0000 - val_loss: 0.4524 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 10/30
# 15/15 [==============================] - 11s 767ms/step - loss: 0.0772 - accuracy: 0.9776 - val_loss: 0.4535 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 11/30
# 15/15 [==============================] - 11s 731ms/step - loss: 0.0481 - accuracy: 1.0000 - val_loss: 0.4478 - val_accuracy: 0.8837
# INFO:tensorflow:Assets written to: .\assets
# Epoch 12/30
# 15/15 [==============================] - 11s 743ms/step - loss: 0.1180 - accuracy: 0.9560 - val_loss: 0.4084 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 13/30
# 15/15 [==============================] - 11s 756ms/step - loss: 0.0560 - accuracy: 0.9871 - val_loss: 0.4204 - val_accuracy: 0.9767
# INFO:tensorflow:Assets written to: .\assets
# Epoch 14/30
# 15/15 [==============================] - 11s 769ms/step - loss: 0.0860 - accuracy: 0.9762 - val_loss: 0.3320 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 15/30
# 15/15 [==============================] - 11s 755ms/step - loss: 0.1266 - accuracy: 0.9551 - val_loss: 0.3345 - val_accuracy: 0.9767
# INFO:tensorflow:Assets written to: .\assets
# Epoch 16/30
# 15/15 [==============================] - 11s 746ms/step - loss: 0.0633 - accuracy: 0.9709 - val_loss: 0.2819 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 17/30
# 15/15 [==============================] - 12s 750ms/step - loss: 0.0619 - accuracy: 0.9788 - val_loss: 0.2255 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 18/30
# 15/15 [==============================] - 11s 770ms/step - loss: 0.0261 - accuracy: 0.9965 - val_loss: 0.2100 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 19/30
# 15/15 [==============================] - 11s 744ms/step - loss: 0.0360 - accuracy: 0.9899 - val_loss: 0.3154 - val_accuracy: 0.8837
# INFO:tensorflow:Assets written to: .\assets
# Epoch 20/30
# 15/15 [==============================] - 12s 772ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1617 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 21/30
# 15/15 [==============================] - 11s 754ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1417 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 22/30
# 15/15 [==============================] - 11s 777ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.1613 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 23/30
# 15/15 [==============================] - 12s 770ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 24/30
# 15/15 [==============================] - 11s 742ms/step - loss: 0.0182 - accuracy: 0.9965 - val_loss: 0.2005 - val_accuracy: 0.9767
# INFO:tensorflow:Assets written to: .\assets
# Epoch 25/30
# 15/15 [==============================] - 11s 763ms/step - loss: 0.0436 - accuracy: 0.9881 - val_loss: 0.1312 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 26/30
# 15/15 [==============================] - 11s 753ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 27/30
# 15/15 [==============================] - 11s 757ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 28/30
# 15/15 [==============================] - 11s 759ms/step - loss: 0.0128 - accuracy: 0.9971 - val_loss: 0.0662 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets
# Epoch 29/30
# 15/15 [==============================] - 12s 766ms/step - loss: 0.0256 - accuracy: 0.9941 - val_loss: 0.2250 - val_accuracy: 0.9302
# INFO:tensorflow:Assets written to: .\assets
# Epoch 30/30
# 15/15 [==============================] - 12s 784ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0435 - val_accuracy: 1.0000
# INFO:tensorflow:Assets written to: .\assets

# %%
acc = history.history['accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
epochs = range(len(history.epoch))

title1 = 'Accuracy vs Validation Accuracy'
leg1 = ['Acc', 'Val_acc']
title2 = 'Loss vs Val_loss'
leg2 = ['Loss', 'Val_loss']

def plot(epochs, acc, val_acc, leg, title):
    mat.plot(epochs, acc)
    mat.plot(epochs, val_acc)
    mat.title(title)
    mat.legend(leg)
    mat.xlabel('epochs')

mat.figure(figsize=(15,5))
mat.subplot(1,2,1)
plot(epochs, acc, val_acc, leg1, title1)
mat.subplot(1,2,2)
plot(epochs, loss, val_loss, leg2, title2)
mat.show()

# %%
import tensorflow.keras.preprocessing.image as im

# %%
samp1, samp2 = [], []
for i in range(10):
    sample_img1 = test_normal+"/" +random.choice(test_dir_normal)
    samp1.append(sample_img1)
    sample_img = test_pneumonia+"/" +random.choice(test_fir_pneumonia)
    samp2.append(sample_img)

mat.figure(figsize = (15, 15))
list1 = [samp1 + samp2]
type1 = 'Normal'
m = 0
j = 1
for k in list1:
    for i in k:
        imagee = im.load_img(i, target_size = (200,200), color_mode = 'grayscale')
        imagee = im.img_to_array(imagee)
        imagee = tf.expand_dims(imagee, axis = 0)
        img = mat.imread(i)
        mat.subplot(4,5,j)
        mat.imshow(img)
        lab = mat.xlabel(type1)
        pred = model.predict(imagee)
        if pred == m:
            lab.set_color('green')
        else:
            lab.set_color('red')
        j+=1
        if j >10:
            type1 = 'Pneumonia'
            m = 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-137-5fbb456583ee> in <module>
#      13 for k in list1:
#      14     for i in k:
# ---> 15         imagee = im.load_img(i, target_size = (200,200), color_mode = 'grayscale')
#      16         imagee = im.img_to_array(imagee)
#      17         imagee = tf.expand_dims(imagee, axis = 0)
#
# D:\anaconda\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     297       ValueError: if interpolation method is not supported.
#     298   """
# --> 299   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     300                         target_size=target_size, interpolation=interpolation)
#     301
#
# D:\anaconda\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xray/test/NORMALNORMAL2-IM-0092-0001.jpeg'
